# %%
import pandas as pd

# %%
test_data = pd.read_csv('test.csv')

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test_data.tail()
# Out:
#      PassengerId  Pclass                          Name     Sex   Age  SibSp  \
# 413         1305       3            Spector, Mr. Woolf    male   NaN      0
# 414         1306       1  Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415         1307       3  Saether, Mr. Simon Sivertsen    male  38.5      0
# 416         1308       3           Ware, Mr. Frederick    male   NaN      0
# 417         1309       3      Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 413      0           A.5. 3236    8.0500   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0              359309    8.0500   NaN        S
# 417      1                2668   22.3583   NaN        C

# %%
test_data = test_data.drop(['Name','SibSp','Parch','Ticket','Fare','Cabin','Embarked'],axis = 1)

# %%
test_data.head()
# Out:
#    PassengerId  Pclass     Sex   Age
# 0          892       3    male  34.5
# 1          893       3  female  47.0
# 2          894       2    male  62.0
# 3          895       3    male  27.0
# 4          896       3  female  22.0

# %%
test_data['Age'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10      True
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22      True
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29      True
#        ...
# 388    False
# 389    False
# 390    False
# 391    False
# 392    False
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# 398    False
# 399    False
# 400    False
# 401    False
# 402    False
# 403    False
# 404    False
# 405    False
# 406    False
# 407    False
# 408     True
# 409    False
# 410     True
# 411    False
# 412    False
# 413     True
# 414    False
# 415    False
# 416     True
# 417     True
# Name: Age, Length: 418, dtype: bool

# %%
test_data['Age'].fillna(test_data['Age'].mean(), inplace = True)

# %%
test_data['Age'].isna().any()
# Out:
# False

# %%
test_data.head()
# Out:
#    PassengerId  Pclass     Sex   Age
# 0          892       3    male  34.5
# 1          893       3  female  47.0
# 2          894       2    male  62.0
# 3          895       3    male  27.0
# 4          896       3  female  22.0

# %%
test_data['first_class'] = test_data['Pclass'].apply(lambda x : 1 if x == 1 else 0)
test_data['second_class'] = test_data['Pclass'].apply(lambda x : 1 if x == 2 else 0)
test_data['third_class'] = test_data['Pclass'].apply(lambda x : 1 if x == 2 else 0)

# %%
test_data = test_data.drop('Pclass',axis = 1)

# %%
test_data.head()
# Out:
#    PassengerId     Sex   Age  first_class  second_class  third_class
# 0          892    male  34.5            0             0            0
# 1          893  female  47.0            0             0            0
# 2          894    male  62.0            0             1            1
# 3          895    male  27.0            0             0            0
# 4          896  female  22.0            0             0            0

# %%
p_id = test_data['PassengerId']

# %%
test_data.drop('PassengerId',axis = 1, inplace = True)

# %%
test_data.head()
# Out:
#       Sex   Age  first_class  second_class  third_class
# 0    male  34.5            0             0            0
# 1  female  47.0            0             0            0
# 2    male  62.0            0             1            1
# 3    male  27.0            0             0            0
# 4  female  22.0            0             0            0

# %%
test_data['Sex'] = test_data['Sex'].map({'male' : 0, 'female' : 1})

# %%
test_data.head()
# Out:
#    Sex   Age  first_class  second_class  third_class
# 0    0  34.5            0             0            0
# 1    1  47.0            0             0            0
# 2    0  62.0            0             1            1
# 3    0  27.0            0             0            0
# 4    1  22.0            0             0            0

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
#model = LogisticRegression()

scaler = StandardScaler()
test_data = scaler.fit_transform(test_data)

# %%
predictions = model.predict(test_data)

# %%
survived = pd.DataFrame({'PassengerId': p_id,'Survived' : predictions})
survived.set_index('PassengerId')
survived.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
survived.to_csv('keggle_predictions1.csv')
